# %%
import csv
import pandas as pd

# %%
csv_path = input("File_Name?")
with open(csv_path, newline="") as csv_file:
    csv_data = csv.reader(csv_file,delimiter=",")
    data_lines= list(csv_data)
    for row in data_lines[0:5]:
        print(row[2])
# Out:
# File_Name?echo_test.csv
# TEMPLATE_WELL
# B13
# B13
# B13
# B13

# %%
with open(csv_path, newline="") as csv_file:
    csv_data = csv.reader(csv_file,delimiter=",")
    data_lines= list(csv_data)
    print(data_lines[1][5])
# Out:
# O01

# %%
with open(csv_path, newline="") as csv_file:
    csv_data = csv.reader(csv_file,delimiter=",")
    for row in csv_data:
        print(row)
# Out:
# ['Index', 'TEMPLATE_PLATE', 'TEMPLATE_WELL', 'TEMPLATE_VOLUME', 'PRIMER1_PLATE', 'PRIMER1_WELL', 'PRIMER1_VOLUME', 'PRIMER2_PLATE', 'PRIMER2_WELL', 'PRIMER2_VOLUME', 'PCR_MIX_PLATE', 'PCR_MIX_WELL', 'PCR_MIX_VOLUME', 'OUTPUT_PLATE', 'OUTPUT_WELL', 'REACTION_NUMBER', 'OPTIMAL_ANNEALING_TEMP', 'THERMOCYCLER_BLOCK', 'THERMOCYCLER_ZONE', 'THERMOCYCLER_ZONE_ANNEALING_TEMP', 'EXPECTED_SIZE']
# ['1', 'templates_plate', 'B13', '1', 'oligos_plate', 'O01', '0.5', 'oligos_plate', 'P01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A01', '7', '62.5', '0', '0', '62.7', '6567']
# ['2', 'templates_plate', 'B13', '1', 'oligos_plate', 'C06', '0.5', 'oligos_plate', 'D06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B01', '41', '62.5', '0', '0', '62.7', '6567']
# ['3', 'templates_plate', 'B13', '1', 'oligos_plate', 'I01', '0.5', 'oligos_plate', 'J01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C01', '4', '62.6', '0', '0', '62.7', '6567']
# ['4', 'templates_plate', 'B13', '1', 'oligos_plate', 'E06', '0.5', 'oligos_plate', 'F06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D01', '42', '62.7', '0', '0', '62.7', '6567']
# ['5', 'templates_plate', 'B13', '1', 'oligos_plate', 'K01', '0.5', 'oligos_plate', 'L01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'E01', '5', '62.7', '0', '0', '62.7', '6567']
# ['6', 'templates_plate', 'B13', '1', 'oligos_plate', 'M04', '0.5', 'oligos_plate', 'N04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'F01', '30', '62.7', '0', '0', '62.7', '6567']
# ['7', 'templates_plate', 'B13', '1', 'oligos_plate', 'I05', '0.5', 'oligos_plate', 'J05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'G01', '36', '62.8', '0', '0', '62.7', '6567']
# ['8', 'templates_plate', 'A13', '1', 'oligos_plate', 'E01', '0.5', 'oligos_plate', 'F01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'H01', '2', '62.9', '0', '0', '62.7', '832']
# ['9', 'templates_plate', 'C13', '1', 'oligos_plate', 'G06', '0.5', 'oligos_plate', 'H06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A02', '43', '63.1', '0', '0', '62.7', '3621']
# ['10', 'templates_plate', 'B13', '1', 'oligos_plate', 'E05', '0.5', 'oligos_plate', 'F05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A03', '34', '63.5', '0', '1', '63.8', '6567']
# ['11', 'templates_plate', 'G13', '1', 'oligos_plate', 'O06', '0.5', 'oligos_plate', 'P06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B03', '47', '63.5', '0', '1', '63.8', '887']
# ['12', 'templates_plate', 'B13', '1', 'oligos_plate', 'M03', '0.5', 'oligos_plate', 'N03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C03', '22', '63.5', '0', '1', '63.8', '6567']
# ['13', 'templates_plate', 'B13', '1', 'oligos_plate', 'G01', '0.5', 'oligos_plate', 'H01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D03', '3', '63.6', '0', '1', '63.8', '6567']
# ['14', 'templates_plate', 'B13', '1', 'oligos_plate', 'M01', '0.5', 'oligos_plate', 'N01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'E03', '6', '63.7', '0', '1', '63.8', '6567']
# ['15', 'templates_plate', 'B13', '1', 'oligos_plate', 'O04', '0.5', 'oligos_plate', 'P04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'F03', '31', '63.8', '0', '1', '63.8', '6567']
# ['16', 'templates_plate', 'B13', '1', 'oligos_plate', 'A05', '0.5', 'oligos_plate', 'B05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'G03', '32', '63.8', '0', '1', '63.8', '6567']
# ['17', 'templates_plate', 'B13', '1', 'oligos_plate', 'K04', '0.5', 'oligos_plate', 'L04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'H03', '29', '63.9', '0', '1', '63.8', '6567']
# ['18', 'templates_plate', 'B13', '1', 'oligos_plate', 'C05', '0.5', 'oligos_plate', 'D05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A04', '33', '64', '0', '1', '63.8', '6567']
# ['19', 'templates_plate', 'B13', '1', 'oligos_plate', 'G03', '0.5', 'oligos_plate', 'H03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B04', '19', '64.5', '0', '1', '63.8', '6567']
# ['20', 'templates_plate', 'B13', '1', 'oligos_plate', 'I03', '0.5', 'oligos_plate', 'J03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A05', '20', '65', '0', '2', '65.7', '6567']
# ['21', 'templates_plate', 'B13', '1', 'oligos_plate', 'O03', '0.5', 'oligos_plate', 'P03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B05', '23', '65.4', '0', '2', '65.7', '6567']
# ['22', 'templates_plate', 'B13', '1', 'oligos_plate', 'C03', '0.5', 'oligos_plate', 'D03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C05', '17', '65.6', '0', '2', '65.7', '6567']
# ['23', 'templates_plate', 'A13', '1', 'oligos_plate', 'C01', '0.5', 'oligos_plate', 'D01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D05', '1', '65.6', '0', '2', '65.7', '230']
# ['24', 'templates_plate', 'B13', '1', 'oligos_plate', 'A04', '0.5', 'oligos_plate', 'B04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'E05', '24', '65.7', '0', '2', '65.7', '6567']
# ['25', 'templates_plate', 'B13', '1', 'oligos_plate', 'G04', '0.5', 'oligos_plate', 'H04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'F05', '27', '65.8', '0', '2', '65.7', '6567']
# ['26', 'templates_plate', 'B13', '1', 'oligos_plate', 'E04', '0.5', 'oligos_plate', 'F04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'G05', '26', '65.9', '0', '2', '65.7', '6567']
# ['27', 'templates_plate', 'B13', '1', 'oligos_plate', 'I04', '0.5', 'oligos_plate', 'J04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'H05', '28', '66', '0', '2', '65.7', '6567']
# ['28', 'templates_plate', 'B13', '1', 'oligos_plate', 'E03', '0.5', 'oligos_plate', 'F03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A06', '18', '66', '0', '2', '65.7', '6567']
# ['29', 'templates_plate', 'B13', '1', 'oligos_plate', 'O05', '0.5', 'oligos_plate', 'P05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B06', '39', '66.2', '0', '2', '65.7', '6567']
# ['30', 'templates_plate', 'B13', '1', 'oligos_plate', 'C04', '0.5', 'oligos_plate', 'D04', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A07', '25', '66.8', '0', '3', '67.4', '6567']
# ['31', 'templates_plate', 'B13', '1', 'oligos_plate', 'A02', '0.5', 'oligos_plate', 'B02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B07', '8', '67', '0', '3', '67.4', '6567']
# ['32', 'templates_plate', 'A13', '1', 'oligos_plate', 'A01', '0.5', 'oligos_plate', 'B01', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C07', '0', '67.2', '0', '3', '67.4', '2104']
# ['33', 'templates_plate', 'B13', '1', 'oligos_plate', 'A06', '0.5', 'oligos_plate', 'B06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D07', '40', '67.2', '0', '3', '67.4', '6567']
# ['34', 'templates_plate', 'B13', '1', 'oligos_plate', 'G02', '0.5', 'oligos_plate', 'H02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'E07', '11', '67.3', '0', '3', '67.4', '6567']
# ['35', 'templates_plate', 'B13', '1', 'oligos_plate', 'G05', '0.5', 'oligos_plate', 'H05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'F07', '35', '67.3', '0', '3', '67.4', '6567']
# ['36', 'templates_plate', 'B13', '1', 'oligos_plate', 'A03', '0.5', 'oligos_plate', 'B03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'G07', '16', '67.3', '0', '3', '67.4', '6567']
# ['37', 'templates_plate', 'B13', '1', 'oligos_plate', 'O02', '0.5', 'oligos_plate', 'P02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'H07', '15', '67.5', '0', '3', '67.4', '6567']
# ['38', 'templates_plate', 'B13', '1', 'oligos_plate', 'M05', '0.5', 'oligos_plate', 'N05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A08', '38', '67.6', '0', '3', '67.4', '6567']
# ['39', 'templates_plate', 'F13', '1', 'oligos_plate', 'M06', '0.5', 'oligos_plate', 'N06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B08', '46', '67.8', '0', '3', '67.4', '2067']
# ['40', 'templates_plate', 'H13', '1', 'oligos_plate', 'M06', '0.5', 'oligos_plate', 'N06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C08', '49', '67.8', '0', '3', '67.4', '2037']
# ['41', 'templates_plate', 'B13', '1', 'oligos_plate', 'C02', '0.5', 'oligos_plate', 'D02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D08', '9', '68', '0', '3', '67.4', '6567']
# ['42', 'templates_plate', 'B13', '1', 'oligos_plate', 'K03', '0.5', 'oligos_plate', 'L03', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A09', '21', '68.6', '0', '4', '68.9', '6567']
# ['43', 'templates_plate', 'B13', '1', 'oligos_plate', 'K02', '0.5', 'oligos_plate', 'L02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B09', '13', '68.8', '0', '4', '68.9', '6567']
# ['44', 'templates_plate', 'B13', '1', 'oligos_plate', 'M02', '0.5', 'oligos_plate', 'N02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C09', '14', '69', '0', '4', '68.9', '6567']
# ['45', 'templates_plate', 'B13', '1', 'oligos_plate', 'I02', '0.5', 'oligos_plate', 'J02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D09', '12', '69.3', '0', '4', '68.9', '6567']
# ['46', 'templates_plate', 'B13', '1', 'oligos_plate', 'E02', '0.5', 'oligos_plate', 'F02', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'A11', '10', '70.3', '0', '5', '71', '6567']
# ['47', 'templates_plate', 'E13', '1', 'oligos_plate', 'K06', '0.5', 'oligos_plate', 'L06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'B11', '45', '70.4', '0', '5', '71', '1222']
# ['48', 'templates_plate', 'B13', '1', 'oligos_plate', 'K05', '0.5', 'oligos_plate', 'L05', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'C11', '37', '71.1', '0', '5', '71', '6567']
# ['49', 'templates_plate', 'G13', '1', 'oligos_plate', 'A07', '0.5', 'oligos_plate', 'B07', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'D11', '48', '71.4', '0', '5', '71', '373']
# ['50', 'templates_plate', 'D13', '1', 'oligos_plate', 'I06', '0.5', 'oligos_plate', 'J06', '0.5', 'PCR_mix_tubes', 'B01', '3', 'assemblytoautomate_PCR_plate_1', 'E11', '44', '71.6', '0', '5', '71', '1342']

# %%
source_well=[]
primer_F_well=[]
primer_R_well=[]

with open(csv_path, newline="") as csv_file:
    csv_data = csv.reader(csv_file,delimiter=",")
    rows= list(csv_data)
    for cols in rows[1:]:
        well_temp = cols[2]
        pri_For_well = cols[5]
        pri_Rev_well = cols[8]
        source_well.append(well_temp)
        primer_F_well.append(pri_For_well)
        primer_R_well.append(pri_Rev_well)
print(source_well)
print(primer_F_well)
print(primer_R_well)
        
#         print(row[2])
# Out:
# ['B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'C13', 'B13', 'G13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'F13', 'H13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'E13', 'B13', 'G13', 'D13']
# ['O01', 'C06', 'I01', 'E06', 'K01', 'M04', 'I05', 'E01', 'G06', 'E05', 'O06', 'M03', 'G01', 'M01', 'O04', 'A05', 'K04', 'C05', 'G03', 'I03', 'O03', 'C03', 'C01', 'A04', 'G04', 'E04', 'I04', 'E03', 'O05', 'C04', 'A02', 'A01', 'A06', 'G02', 'G05', 'A03', 'O02', 'M05', 'M06', 'M06', 'C02', 'K03', 'K02', 'M02', 'I02', 'E02', 'K06', 'K05', 'A07', 'I06']
# ['P01', 'D06', 'J01', 'F06', 'L01', 'N04', 'J05', 'F01', 'H06', 'F05', 'P06', 'N03', 'H01', 'N01', 'P04', 'B05', 'L04', 'D05', 'H03', 'J03', 'P03', 'D03', 'D01', 'B04', 'H04', 'F04', 'J04', 'F03', 'P05', 'D04', 'B02', 'B01', 'B06', 'H02', 'H05', 'B03', 'P02', 'N05', 'N06', 'N06', 'D02', 'L03', 'L02', 'N02', 'J02', 'F02', 'L06', 'L05', 'B07', 'J06']

# %%
source_well.extend(primer_F_well)
source_well.extend(primer_R_well)


print(source_well)
# Out:
# ['B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'C13', 'B13', 'G13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'A13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'F13', 'H13', 'B13', 'B13', 'B13', 'B13', 'B13', 'B13', 'E13', 'B13', 'G13', 'D13', 'O01', 'C06', 'I01', 'E06', 'K01', 'M04', 'I05', 'E01', 'G06', 'E05', 'O06', 'M03', 'G01', 'M01', 'O04', 'A05', 'K04', 'C05', 'G03', 'I03', 'O03', 'C03', 'C01', 'A04', 'G04', 'E04', 'I04', 'E03', 'O05', 'C04', 'A02', 'A01', 'A06', 'G02', 'G05', 'A03', 'O02', 'M05', 'M06', 'M06', 'C02', 'K03', 'K02', 'M02', 'I02', 'E02', 'K06', 'K05', 'A07', 'I06', 'P01', 'D06', 'J01', 'F06', 'L01', 'N04', 'J05', 'F01', 'H06', 'F05', 'P06', 'N03', 'H01', 'N01', 'P04', 'B05', 'L04', 'D05', 'H03', 'J03', 'P03', 'D03', 'D01', 'B04', 'H04', 'F04', 'J04', 'F03', 'P05', 'D04', 'B02', 'B01', 'B06', 'H02', 'H05', 'B03', 'P02', 'N05', 'N06', 'N06', 'D02', 'L03', 'L02', 'N02', 'J02', 'F02', 'L06', 'L05', 'B07', 'J06']

# %%
df = pd.DataFrame(source_well, columns=['Source Well'])

df.head()
# Out:
#   Source Well
# 0         B13
# 1         B13
# 2         B13
# 3         B13
# 4         B13

# %%
pwd
# Out:
# '/Users/nkaplan/Desktop'

# %%
Destination_well=[]


with open(csv_path, newline="") as csv_file:
    csv_data = csv.reader(csv_file,delimiter=",")
    data_lines= list(csv_data)
    for row in data_lines[1:]:
        Dest_Well = row[14]
        Destination_well.append(Dest_Well)
        
print(Destination_well)
# Out:
# ['A01', 'B01', 'C01', 'D01', 'E01', 'F01', 'G01', 'H01', 'A02', 'A03', 'B03', 'C03', 'D03', 'E03', 'F03', 'G03', 'H03', 'A04', 'B04', 'A05', 'B05', 'C05', 'D05', 'E05', 'F05', 'G05', 'H05', 'A06', 'B06', 'A07', 'B07', 'C07', 'D07', 'E07', 'F07', 'G07', 'H07', 'A08', 'B08', 'C08', 'D08', 'A09', 'B09', 'C09', 'D09', 'A11', 'B11', 'C11', 'D11', 'E11']

# %%
Destination_well_Final= 3*Destination_well
len(Destination_well_Final)
# Out:
# 150

# %%
df['Destination well'] = Destination_well_Final

# %%
df
# Out:
#     Source Well Destination well
# 0           B13              A01
# 1           B13              B01
# 2           B13              C01
# 3           B13              D01
# 4           B13              E01
# 5           B13              F01
# 6           B13              G01
# 7           A13              H01
# 8           C13              A02
# 9           B13              A03
# 10          G13              B03
# 11          B13              C03
# 12          B13              D03
# 13          B13              E03
# 14          B13              F03
# 15          B13              G03
# 16          B13              H03
# 17          B13              A04
# 18          B13              B04
# 19          B13              A05
# 20          B13              B05
# 21          B13              C05
# 22          A13              D05
# 23          B13              E05
# 24          B13              F05
# 25          B13              G05
# 26          B13              H05
# 27          B13              A06
# 28          B13              B06
# 29          B13              A07
# ..          ...              ...
# 120         P03              B05
# 121         D03              C05
# 122         D01              D05
# 123         B04              E05
# 124         H04              F05
# 125         F04              G05
# 126         J04              H05
# 127         F03              A06
# 128         P05              B06
# 129         D04              A07
# 130         B02              B07
# 131         B01              C07
# 132         B06              D07
# 133         H02              E07
# 134         H05              F07
# 135         B03              G07
# 136         P02              H07
# 137         N05              A08
# 138         N06              B08
# 139         N06              C08
# 140         D02              D08
# 141         L03              A09
# 142         L02              B09
# 143         N02              C09
# 144         J02              D09
# 145         F02              A11
# 146         L06              B11
# 147         L05              C11
# 148         B07              D11
# 149         J06              E11
#
# [150 rows x 2 columns]

# %%
Temp_vol= int(input("Template DNA volume(ul): ?"))
# Out:
# Template DNA volume(ul): ?1000

# %%
Primer_For_vol= int(input("Primer (Forward) volume(ul): ?"))
# Out:
# Primer (Forward) volume(ul): ?600

# %%
Primer_Rev_vol= int(input("Primer (Reverse) volume(ul): ?"))
# Out:
# Primer (Reverse) volume(ul): ?600

# %%
rn_num = df.count()[0]
rn_num
# Out:
# 150

# %%
temp_vol_list= [Temp_vol]
temp_vol_list=temp_vol_list*(int(rn_num/3))

primer_F_vol_list= [Primer_For_vol]
primer_F_vol_list = primer_F_vol_list*(int(rn_num/3))

primer_R_vol_list= [Primer_Rev_vol]
primer_R_vol_list = primer_R_vol_list*(int(rn_num/3))

primer_R_vol_list

temp_vol_list.extend(primer_F_vol_list)
temp_vol_list.extend(primer_R_vol_list)
Final_vol_list= temp_vol_list

# %%
Final_vol_list
# Out:
# [1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600,
#  600]

# %%
len(Final_vol_list)
# Out:
# 150

# %%
df["Transfer Volume"]= Final_vol_list
df.head()
# Out:
#   Source Well Destination well  Transfer Volume
# 0         B13              A01             1000
# 1         B13              B01             1000
# 2         B13              C01             1000
# 3         B13              D01             1000
# 4         B13              E01             1000

# %%
df
# Out:
#     Source Well Destination well  Transfer Volume
# 0           B13              A01             1000
# 1           B13              B01             1000
# 2           B13              C01             1000
# 3           B13              D01             1000
# 4           B13              E01             1000
# 5           B13              F01             1000
# 6           B13              G01             1000
# 7           A13              H01             1000
# 8           C13              A02             1000
# 9           B13              A03             1000
# 10          G13              B03             1000
# 11          B13              C03             1000
# 12          B13              D03             1000
# 13          B13              E03             1000
# 14          B13              F03             1000
# 15          B13              G03             1000
# 16          B13              H03             1000
# 17          B13              A04             1000
# 18          B13              B04             1000
# 19          B13              A05             1000
# 20          B13              B05             1000
# 21          B13              C05             1000
# 22          A13              D05             1000
# 23          B13              E05             1000
# 24          B13              F05             1000
# 25          B13              G05             1000
# 26          B13              H05             1000
# 27          B13              A06             1000
# 28          B13              B06             1000
# 29          B13              A07             1000
# ..          ...              ...              ...
# 120         P03              B05              600
# 121         D03              C05              600
# 122         D01              D05              600
# 123         B04              E05              600
# 124         H04              F05              600
# 125         F04              G05              600
# 126         J04              H05              600
# 127         F03              A06              600
# 128         P05              B06              600
# 129         D04              A07              600
# 130         B02              B07              600
# 131         B01              C07              600
# 132         B06              D07              600
# 133         H02              E07              600
# 134         H05              F07              600
# 135         B03              G07              600
# 136         P02              H07              600
# 137         N05              A08              600
# 138         N06              B08              600
# 139         N06              C08              600
# 140         D02              D08              600
# 141         L03              A09              600
# 142         L02              B09              600
# 143         N02              C09              600
# 144         J02              D09              600
# 145         F02              A11              600
# 146         L06              B11              600
# 147         L05              C11              600
# 148         B07              D11              600
# 149         J06              E11              600
#
# [150 rows x 3 columns]

# %%
echo_ins = input("Name Echo file?")
# Out:
# Name Echo file?test_echo_blablabla

# %%
df.to_csv(f"{echo_ins}.csv")
